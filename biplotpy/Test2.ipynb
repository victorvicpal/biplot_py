# %%
import ClassicBip

# %%
from sklearn import datasets
import pandas as pd
iris = datasets.load_iris()
y = iris.target
col_names = iris.feature_names
X = pd.DataFrame(iris.data, columns = col_names)
Group = iris.target_names

# %%
B = ClassicBip.ClassicBip(alpha=1,data=X,dim=3)

# %%
B.biplot(method=1)

# %%
import bipplot

# %%
bipplot.plot(B, target = y,dim=[0,1])

# %%
import Feature_selection

# %%
import numpy as np

# %%
T = Feature_selection.Feature_selection(B,target=y,thr_dis=50,thr_corr=0.9)
