# %%
import ClassicBip

# %%
import pandas as pd
Data = pd.read_csv('/Users/victor/Documents/DataLab/2018/ML_test/data/train.csv')

# %%
Data = Data.fillna(Data.mean())
X = Data.iloc[:,:-1]
y = Data.num
col_names = X.columns
Group = list(Data.num.unique())

# %%
Group
# Out:
# [0, 2, 1, 3, 4]

# %%
B = ClassicBip.ClassicBip(alpha=1,data=X,dim=8)

# %%
B.biplot(method=1)

# %%
import bipplot

# %%
bipplot.plot(B, target = y,dim=[0,1])

# %%
import Feature_selection

# %%
T = Feature_selection.Feature_selection(B,target=y,thr_dis=75,thr_corr=0.9, type_cor="coord")

# %%
global_cor = T.var_sel

# %%
global_cor
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'exang', 'oldpeak', 'ca', 'thal']
