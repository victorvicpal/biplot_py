# %%
import CanonicalBip
import pandas as pd

# %%
wine = pd.read_csv('/Users/victor/Documents/DataLab/2018/wine.csv')

# %%
target = list(wine.iloc[:,2])
X = wine.iloc[:,3:]

# %%
Group = list(set(target))

# %%
BCan = CanonicalBip.CanonicalBip(data=X,dim=3,GroupNames=Group,y=target)

# %%
BCan.CanonicalBip(method=1)

# %%
BCan.Radius
# Out:
# {'Bonf': array([ 0.23393789,  0.1531483 ,  0.25626612,  0.12813306]),
#  'Chis': array([ 0.15606265,  0.10216699,  0.17095807,  0.08547903]),
#  'Mult': array([ 0.50674582,  0.33174301,  0.55511223,  0.27755612]),
#  'Uni': array([ 0.12876123,  0.08429401,  0.14105086,  0.07052543])}

# %%
import bipplot

# %%
bipplot.plot(BCan, figx = 12, figy = 12, xlim = [-4,4], ylim = [-4,4], arrow_width = 0.01)

# %%
BCan.Group_Coord
# Out:
# array([[ 0.21902539, -0.00603543, -0.0002902 ],
#        [-0.18985335, -0.12651107, -0.00100128],
#        [-0.17864204,  0.2390999 , -0.00667916],
#        [-0.13822511,  0.11606066,  0.00886962]])

# %%
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
circles = []
for i, el in enumerate(BCan.GroupNames):
    circles.append(plt.Circle(BCan.Group_Coord[0, [0,1]], BCan.Radius['Bonf'][i], alpha = 0.4))
