# %%
import CanonicalBip
import pandas as pd

# %%
wine = pd.read_csv('/Users/victor/Documents/DataLab/2018/wine.csv')

# %%
target = list(wine.iloc[:,2])
X = wine.iloc[:,3:]

# %%
Group = list(set(target))

# %%
BCan = CanonicalBip.CanonicalBip(data=X,dim=3,GroupNames=Group,y=target)

# %%
BCan.CanonicalBip(method=1)

# %%
import bipplot

# %%
bipplot.plot(BCan, figx = 12, figy = 12, xlim = [-4,4], ylim = [-4,4], arrow_width = 0.01)

# %%
y = []
for tar in target:
    if tar == 'R86':
        y.append(0)
    elif tar == 'R87':
        y.append(1)
    elif tar == 'T86':
        y.append(2)
    else:
        y.append(3)

# %%
import Feature_selection
import numpy as np

# %%
T = Feature_selection.Feature_selection(BCan,np.array(y),type_cor='global')

# %%
T.var_sel
# Out:
# ['TA', 'FA', 'TPR', 'TPS', 'V', 'PC', 'ACR', 'ACS', 'ACC', 'CI2', 'H', 'I']
