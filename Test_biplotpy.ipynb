# %%
import biplotpy as bp

# %%
from sklearn import datasets
iris = datasets.load_iris()
data = iris.data

# %%
bip = bp.biplotpy(data,dim=3,alpha=1)

# %%
bip.CanonicalBip(iris.feature_names,iris.target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a9ecd05768a7> in <module>()
# ----> 1 bip.CanonicalBip(iris.feature_names,iris.target)
#
# /Users/victor/Documents/DataLab/2018/biplot_py/biplotpy.py in CanonicalBip(self, GroupNames, y, std)
#     177                 self.Group_Coord = J
#     178                 #Individual_Coord
# --> 179                 V = X_st.dot(B)
#     180                 self.Ind_Coord = V
#
# NameError: name 'X_st' is not defined

# %%
bip.plot_bip(col_names=iris.feature_names,labels=iris.target)
